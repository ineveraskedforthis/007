# %% [markdown]
# ### le data science lmaooooooooo

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("market_activity.txt")

# %%
data["activity"].plot()
# Out:
# <AxesSubplot: >

# %%
data["debt"].plot()
# Out:
# <AxesSubplot: >
